# %%
import pandas as pd
df = pd.read_csv("selected_features_lasso.csv")
df.head()
# Out:
#    social_media_frequency   age  marital_status  living_arrangement  \
# 0                     1.0  60.0             1.0                 3.0
# 1                     3.0  32.0             1.0                 3.0
# 2                     6.0  49.0             1.0                 2.0
# 3                     5.0  70.0             1.0                 2.0
# 4                     7.0  60.0             1.0                 3.0
#
#    emotional_stability  intellect_imagination  self_esteem  Self-Rated_Health  \
# 0                  4.3                    3.9          6.2                  3
# 1                  2.7                    3.4          5.2                  2
# 2                  2.6                    3.3          3.9                  3
# 3                  4.1                    3.3          5.8                  3
# 4                  4.2                    3.8          6.1                  3
#
#    Health_Hindrance_to_Daily_Functioning  Sleeping_Problems  \
# ...

# %%
df.columns
# Out:
# Index(['social_media_frequency', 'age', 'marital_status', 'living_arrangement',
#        'emotional_stability', 'intellect_imagination', 'self_esteem',
#        'Self-Rated_Health', 'Health_Hindrance_to_Daily_Functioning',
#        'Sleeping_Problems', 'Personal_Net_Income_Category',
#        'Employment_status', 'hours_on_social_media'],
#       dtype='object')

# %%
#let op!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!maar er is hier een fout. ik moet MHI5_class_2022 eerst mergen met lassofeatureset.
import pandas as pd
# Load dataset
df_for_target = pd.read_csv("social_demographic.csv")  

# Define the target variable
target_column = df_for_target['mhi5_class_2022']

# Load dataset
df = pd.read_csv("selected_features_lasso.csv")  

# Separate features and target
X = df  # Drop target + uncertain columns for training
y = target_column  # Target variable

# %%
#########let op eerst mergen volgens mij
#make X and y columns align
X= X.reset_index(drop=True)
y= y.reset_index(drop=True)

print(X.isna().sum()) 

print("---------------------------------------------------------------------")
print(y.isna().sum())
print(y.dtype)
